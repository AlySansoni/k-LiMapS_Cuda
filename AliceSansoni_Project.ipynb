# %% [markdown]
# # CUDA SetUp

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !nvidia-smi
# Out:
# Wed Feb 23 15:03:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # NVCC Plugin for Jupyter notebook
#
# Usage:
#
# Load Extension %load_ext nvcc_plugin
# Mark a cell to be treated as cuda cell %%cuda --name example.cu --compile false
# NOTE: The cell must contain either code or comments to be run successfully. It accepts 2 arguments. -n | --name - which is the name of either CUDA source or Header. The name parameter must have extension .cu or .h. Second argument -c | --compile; default value is false. The argument is a flag to specify if the cell will be compiled and run right away or not. It might be usefull if you're playing in the main function
#
# We are ready to run CUDA C/C++ code right in your Notebook. For this we need explicitly say to the interpreter, that we want to use the extension by adding %%cu at the beginning of each cell with CUDA code.

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# ...
#   Cloning git://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-cxsfho02
#   Running command git clone -q git://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-cxsfho02
# ...
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-py3-none-any.whl size=4306 sha256=464259f81b2a8f75e95bc371efccd3228b42f11bf059679339d6ae913759c8c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-visomz_7/wheels/c5/2b/c0/87008e795a14bbcdfc7c846a00d06981916331eb980b6c8bdf
# Successfully built NVCCPlugin
# ...

# %%
# %load_ext nvcc_plugin
# Out:
# created output directory at /content/src
# Out bin /content/result.out

# %%
# %cd /content/drive/MyDrive/GPUcomputing/Project
# %ls
# Out:
# /content/drive/MyDrive/GPUcomputing/Project
# AliceSansoni_Project.ipynb  k_limaps_GPU_stream.cu
# a.out                       k_limaps_GPU_stream_no.cu
# Backup/                     k_limaps_GPU_stream_shared.cu
# deviceQuery                 klimgpu
# deviceQuery.cu              klimGPU
# example.c                   klimGPUPseudo
# example.o                   klimGPUShared
# function_test.cu            klimGPUStream
# gsl/                        klimGPUStreamShared
# gsl-2.7/                    klimPseudoInv
# gsl-2.7.tar.gz              klimStream
# gsl-latest.tar.gz           matlin
# helper.h                    pinv
# install.sh                  prova_mat_lineare.c
# install.sh.1                pseudoinv
# install.sh.2                pseudoinv.cu
# install.sh.3                pseudoinv_example.c
# install.sh.4                psinv
# install.sh.5                stream
# install.sh.6                streamEx.cu
# install.sh.7                test
# ...

# %% [markdown]
# # ✔ DeviceQuery

# %%
# DeviceQuery dell'attuale device
# !nvcc -arch=sm_60 /content/drive/MyDrive/GPUcomputing/Project/deviceQuery.cu -o deviceQuery
# %cd /content/drive/MyDrive/GPUcomputing/Project
# !./deviceQuery
# Out:
# /content/drive/MyDrive/GPUcomputing/Project
#
# CUDA Device Query (Runtime API) version (CUDART static linking)
#
# Detected 1 CUDA Capable device(s)
#
# Device 0: "Tesla P100-PCIE-16GB"
#   CUDA Driver Version / Runtime Version          11.2 / 11.1
#   CUDA Capability Major/Minor version number:    6.0
#   Total amount of global memory:                 16281 MBytes (17071734784 bytes)
#   (56) Multiprocessors, ( 64) CUDA Cores/MP:     3584 CUDA Cores
#   GPU Max Clock rate:                            1329 MHz (1.33 GHz)
#   Memory Clock rate:                             715 Mhz
#   Memory Bus Width:                              4096-bit
#   L2 Cache Size:                                 4194304 bytes
#   Maximum Texture Dimension Size (x,y,z)         1D=(131072), 2D=(131072, 65536), 3D=(16384, 16384, 16384)
#   Maximum Layered 1D Texture Size, (num) layers  1D=(32768), 2048 layers
#   Maximum Layered 2D Texture Size, (num) layers  2D=(32768, 32768), 2048 layers
# ...

# %% [markdown]
# # VS code on Colab

# %%
# 1. Install the colab-code package...
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 45 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 8.3 MB 26.8 MB/s
# ...
#      |████████████████████████████████| 745 kB 68.0 MB/s
# ...
#      |████████████████████████████████| 61 kB 10.1 MB/s
# ...
#      |████████████████████████████████| 428 kB 67.4 MB/s
# ...
#      |████████████████████████████████| 397 kB 69.8 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 10.1 MB/s
# ...
#      |████████████████████████████████| 130 kB 69.2 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 130 kB 74.1 MB/s
# ...
#      |████████████████████████████████| 129 kB 70.2 MB/s
# ...
#      |████████████████████████████████| 125 kB 60.0 MB/s
# ...
#      |████████████████████████████████| 124 kB 78.4 MB/s
# ...
#      |████████████████████████████████| 124 kB 67.3 MB/s
# ...
#      |████████████████████████████████| 122 kB 81.2 MB/s
# ...
#      |████████████████████████████████| 122 kB 78.7 MB/s
# ...

# %%
# 2. Import and launch...
from colabcode import ColabCode
ColabCode(port=10000, password=None, authtoken="23pixGZ4mYP4eYrtfvIWaAk9apN_5BAV3qr2ozkSgafRVKWnU", mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://271d-35-204-91-114.ngrok.io" -> "http://localhost:10000"
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [2022-02-23T15:04:28.203Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2022-02-23T15:04:28.205Z] info  Using user-data-dir ~/.local/share/code-server
# [2022-02-23T15:04:28.218Z] info  Using config file ~/.config/code-server/config.yaml
# [2022-02-23T15:04:28.218Z] info  HTTP server listening on http://127.0.0.1:10000
# [2022-02-23T15:04:28.219Z] info    - Authentication is disabled
# [2022-02-23T15:04:28.219Z] info    - Not serving HTTPS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0e2f2c01b69b> in <module>()
#       1 # 2. Import and launch...
#       2 from colabcode import ColabCode
# ...
